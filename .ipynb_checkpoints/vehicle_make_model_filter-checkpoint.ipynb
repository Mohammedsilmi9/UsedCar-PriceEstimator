# %%
from bs4 import BeautifulSoup
from pandas import DataFrame
from time import sleep
import urllib.request
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import requests
import datetime
import requests
import glob   
import os
import io
import re

# %%
make_model_keys=pd.read_html('https://www.kbb.com/car-make-model-list/new/view-all/')

# %%
df_make_model=pd.DataFrame(make_model_keys[0])

# %%
df_make_model=df_make_model[['Make','Model']]

# %%
make=result

# %%
collection_df = pd.DataFrame()
for f in glob.glob(r"C:\Users\Silmi\Desktop\UsedCar-PriceEstimator\data\*.csv"):
    appenddata = pd.read_csv(f)
    collection_df = collection_df.append(appenddata)

# %%
collection_df.shape
# Out:
# (26991, 16)

# %%
collection_df.drop_duplicates(inplace=True)
collection_df.shape
# Out:
# (21502, 16)

# %%
df_=collection_df.copy()

# %%
df_.shape
# Out:
# (21502, 16)

# %%
df_['make:'].nunique()
# Out:
# 446

# %%
df_['make:'].replace(['mazda','MAZDA'],'mazda',inplace=True)
df_['make:'].replace(['MITSUBISHI'],'mitsubishi',inplace=True)
df_['make:'].replace(['mercedes','Mercedes-benz','Mercedez','Mersedes','mbz','Mbz',
                      'mercedez','mercedes-benz','Mercedes',
                      'Benz','MERCEDES','Merceds','MERCEDES-BENZ',
                      'Mercedes-Benz','mersedes'],'mercedes-benz',inplace=True)
df_['make:'].replace([ 'Cevrolet','Chaey','Chebrolet','Chevelle','Chevorlet','Chevroler',
                      'Chevrolet','Chevrolete','Chevy.','chevrolet','Chverolet','Shevrolet',
                      'chevrolet','Chevi','CHEVY','Chevrolet',
                      'chevorlet','chevy','CHEVRLET','Cheverolet','Chevy','Chev',
                      'CHEVROLET','chev'],'chevrolet',inplace=True)
df_['make:'].replace(['volkseagen','volkswagon','volkwagen', 'Volkswagon',
                      'Volkswangen','Volkwagen','volkswagen',
                      'Vw','VW','vw','VOLKSWAGEN','V.W'],'volkswagen',inplace=True)
df_['make:'].replace(['TOYOYA','toyta','Toyot','Toyoda','TOYOTA',
                      'toyota'],'toyota',inplace=True)
df_['make:'].replace(['Mini','MINI'],'mini',inplace=True)
df_['make:'].replace(['Isuzu','Izusu','Izuzu','izuzu','isuzu'],'isuzu',inplace=True)
df_['make:'].replace(['hyndai','hynduia','Hyuandi','Hunday','hundai','hyundia',
                      'HYUNDAI'],'hyundai',inplace=True)
df_['make:'].replace(['Bmw','bimmer','Bmw'],'bmw',inplace=True)
df_['make:'].replace(['Audi','AUDI'],'audi',inplace=True)
df_['make:'].replace(['LEXUS','Lexus'],'lexus',inplace=True)
df_['make:'].replace(['KIA','Kia'],'kia',inplace=True)
df_['make:'].replace(['Ford','FORD','for'],'ford',inplace=True)
df_['make:'].replace(['HUMMER','Hummer','hummer','Gmc','GMC','Gmc'],'gmc',inplace=True)
df_['make:'].replace(['HONDA','Houda','honda'],'Honda',inplace=True)
df_['make:'].replace(['jeep','Jeeb','JEEP'],'Jeep',inplace=True)
df_['make:'].replace(['audi','AUDI'],'Audi',inplace=True)
df_['make:'].replace(['VOLVO', 'volvo'],'Volvo',inplace=True)
df_['make:'].replace(['Infinti','infinti','INFINITI','infiniti',
                      'infinity'],'Infinity',inplace=True)
df_['make:'].replace(['FIAT', 'fiat'],'Fiat',inplace=True)
df_['make:'].replace(['Nissin','NISSAN','Nissan'],'nissan',inplace=True)
df_['make:'].replace(['PORSCHE','porsche'],'Porsche',inplace=True)
df_['make:'].replace(['model','Model','TESLA','TELSA','Tesla'],'tesla',inplace=True)
df_['make:'].replace(['alfa Romeo','Alfa','alfa'],'Alfa Romeo',inplace=True)
df_['make:'].replace(['land-rover','LANDROVER','Rover','rover','land','Land rover',
                      'land rover'],'land rover',inplace=True)
df_['make:'].replace([ 'chryler','chrystler','chyrsler','chysler',
                      'chrysler','CRYSLER','Cheysler'],'chrysler',inplace=True)
df_['make:'].replace(['pontaic','pontiac'],'pontiac',inplace=True)

# %%
df_['make:'].nunique()
# Out:
# 339

# %%
df_['make:']=df_['make:'].apply(lambda x: x.lower())

# %%
df_['make:'].unique()
# Out:
# array(['mini', 'mercedes-benz', 'volkswagen', 'chevrolet', 'bmw', 'honda',
#        'ford', 'bluebird', 'tesla', 'toyota', 'audi', 'hyundai', 'dodge',
#        'acura', 'porsche', 'gmc', 'suzuki', 'lexus', 'jeep', 'nissan',
#        'caddilac', 'maserati', 'mazda', 'volvo', 'cadillac', 'subaru',
#        'jaguar', 'kia', 'mitsubishi', 'land', 'lincoln', 'buick',
#        'pontiac', 'es', 'infinity', 'chrysler', 'plymouth', 'southwest',
#        'saturn', 'impreza', 'kenworth', 'land rover', 'isuzu', 'mercury',
#        'scion', 'corolla', 'a4', 'willys', 'lamborghini', 'today', 'ram',
#        'oldsmobile', 'range', 'corvette', 'huyndai', 'alfa romeo', 'saab',
#        'hemi', 'triumph', 'porch', 'datson', 'rolls', 'freightliner',
#        'shelby', 'hino', '--', 'international', 'for', 'clk55', 'fiat',
#        'datsun', 'suihe', 'fleetwood', 'pt', 'mustang', 'wolkswagen',
#        'chevy3500', 'olds', 'infiniti', 'mazada', '300td', 'nissian',
#        'sienna', 'desoto', 'mg', 'renault', 'qx80', 'studebaker', 'vin',
#        'smart', 'm3', 'am', 'winnebago', 'amc', 'ferrari', 'mgb', 'chvey',
#        'peterbilt', 'fordf350', 'piontiac', 'landrover', 'ffr',
#        'plymouth,', 'genesis', 'acrua', 'touota', 'no', 'vaz', 'c',
#        'prius', 'bentley', 'toytoa', 'hightop', 'cualquier', 'f350',
#        'ptrb-', 'used', 'jeepster', 'mbz', 'toyata', 'reo,', 'subary',
#        'aston', 'el', 'masarati', 'maybach', 'infinite', 'amg', 'tonw',
#        'mecury', 'buick,', 'convertible', 'sand', 'komatsu', 'monte',
#        'crown', 'hudson', 'galaxie', 'camaro', 'yamaha', 'g6', 'se',
#        'american', 'nx200t', 'toyota/camry', 'harley', 'ford.', 'grand',
#        'cheyenne', 'hyudai', 'mercedz', 'ls', 'silver', 'chevelle',
#        'linc', 'to', 'madaz', 'mazdaspeed', 'cl', '911', 'morgan',
#        'citroen', 'kawasaki', 'lincon', 'police', 'outlander', 'integra',
#        'civic', 'cadillac/', 'eagle', 'scin', "92'", '-', 'accord',
#        'volkswagon', 'freight', 'gm', 'avanti', 'bww', 'gl', 'roush',
#        'suzu', 'thor', 'cheverolet', 'sterling', 'model', '01volvo',
#        'toyotatacoma', 'keep', 'electric', 'bobcat', 'polaris', 'pontica',
#        'fraightliner', '528i', 'year', 'celica', 'morris', 'boattail',
#        'glc', 'aucra', 'lada', '2006.', 'austin', '02nissan', 'mci',
#        'lug', 'f250', 'merdedes', 'thomas', 'frieghtliner', '2016d',
#        'bel', 'very', 'blue', 'tahoe', 'doge', 'rx', 'highlander',
#        'jetta', 'ml', 'rambler', 'silverado', 'c63s', 'petterbuilt',
#        'suburban', 'fonda', 'fd', 'ducati', 'lifted', 'nisaan', 'van',
#        'firebird', "'09", 'bmx', 'pontaic', 'geo', 'howe', 'fird',
#        'chrsyler', 'gs350', 'riley', 'totota', 'jensen', 'sprinter',
#        'limited', 'leaf', 'bnw', 'plug', '2016audi', 'dakota', 'gem',
#        'hendrickson', 'mdl', '95-04', 'quick', 'goben', 'hyandai',
#        'pontac', 'c-10', 'daewoo'], dtype=object)

# %%
df=collection_df[collection_df['make:'].isin(make)]

# %%
df_not=collection_df[collection_df['make:'].isin(make)]

# %%
df.shape
# Out:
# (7391, 16)

# %%
#df_filter=df[df['model:'].isin(model_list)]
df['make:'].unique()
# Out:
# array(['chevrolet', 'volkswagen', 'tesla', 'hyundai', 'dodge', 'acura',
#        'suzuki', 'jeep', 'nissan', 'maserati', 'volvo', 'cadillac',
#        'jaguar', 'porsche', 'mitsubishi', 'lincoln', 'pontiac',
#        'chrysler', 'infiniti', 'subaru', 'buick', 'oldsmobile', 'saab',
#        'ram', 'fiat', 'ferrari', 'bentley', 'honda', 'audi', 'gmc',
#        'ford', 'toyota', 'bmw', 'kia', 'lexus', 'mazda', 'mercedes-benz',
#        'mini', 'genesis'], dtype=object)

# %%
df=df.iloc[:,2:16]

# %%
df.describe()
# Out:
#           odometer:         price:
# count  7.391000e+03    7375.000000
# mean   1.278131e+05   11167.163661
# std    2.221514e+05   13602.339147
# min    0.000000e+00       0.000000
# 25%    6.941500e+04    4000.000000
# 50%    1.190000e+05    6900.000000
# 75%    1.647170e+05   13200.000000
# max    1.000000e+07  199900.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7391 entries, 9 to 2762
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   make:          7391 non-null   object
#  1   model:         7391 non-null   object
#  2   trim:          3443 non-null   object
#  3   VIN:           964 non-null    object
#  4   condition:     5785 non-null   object
#  5   odometer:      7391 non-null   int64
#  6   cylinders:     5429 non-null   object
#  7   color:         5050 non-null   object
#  8   transmission:  7391 non-null   object
#  9   type:          4555 non-null   object
#  10  status:        7391 non-null   object
#  11  drive:         4662 non-null   object
#  12  fuel:          7391 non-null   object
#  13  price:         7375 non-null   float64
# dtypes: float64(1), int64(1), object(12)
# memory usage: 866.1+ KB

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('Car Price Distribution Plot')
sns.distplot(df['price:'])

plt.subplot(1,2,2)
plt.title('Car Price Spread')
sns.boxplot(y=df["price:"])

plt.show()

# %%
plt.figure(figsize=(25, 6))

plt.subplot(1,3,1)
plt1 = df['make:'].value_counts().plot(kind='bar')
plt.title('Companies Histogram')
plt1.set(xlabel = 'Car company', ylabel='Frequency of company')

plt.subplot(1,3,2)
plt1 = df['fuel:'].value_counts().plot(kind='bar')
plt.title('Fuel Type Histogram')
plt1.set(xlabel = 'Fuel Type', ylabel='Frequency of fuel type')

plt.subplot(1,3,3)
plt1 = df['status:'].value_counts().plot(kind='bar')
plt.title('Car Type Histogram')
plt1.set(xlabel = 'Car title', ylabel='Frequency of Car title status')

plt.show()

# %%
df.columns
# Out:
# Index(['make:', 'model:', 'trim:', 'VIN:', 'condition:', 'odometer:',
#        'cylinders:', 'color:', 'transmission:', 'type:', 'status:', 'drive:',
#        'fuel:', 'price:'],
#       dtype='object')

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('cylinders Histogram')
sns.countplot(df['cylinders:'], palette=("cubehelix"))

plt.subplot(1,2,2)
plt.title('cylinders vs Price')
sns.boxplot(x=df['cylinders:'], y=df['price:'], palette=("cubehelix"))

plt.show()

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('transmission Histogram')
sns.countplot(df['transmission:'], palette=("cubehelix"))

plt.subplot(1,2,2)
plt.title('transmission vs Price')
sns.boxplot(x=df['transmission:'], y=df['price:'], palette=("cubehelix"))

plt.show()
